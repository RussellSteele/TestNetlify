# %%
library(tidyverse)
library(rstan)
library(foreign)
library(here)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.0.0     ✔ purrr   0.2.5
# ✔ tibble  1.4.2     ✔ dplyr   0.7.6
# ✔ tidyr   0.8.1     ✔ stringr 1.3.0
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# Warning message:
# “package ‘ggplot2’ was built under R version 3.4.4”Warning message:
# “package ‘tibble’ was built under R version 3.4.3”Warning message:
# “package ‘tidyr’ was built under R version 3.4.4”Warning message:
# “package ‘purrr’ was built under R version 3.4.4”Warning message:
# “package ‘dplyr’ was built under R version 3.4.4”Warning message:
# “package ‘stringr’ was built under R version 3.4.3”Warning message:
# “package ‘forcats’ was built under R version 3.4.3”── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Warning message:
# “package ‘rstan’ was built under R version 3.4.3”Loading required package: StanHeaders
# Warning message:
# “package ‘StanHeaders’ was built under R version 3.4.3”rstan (Version 2.17.3, GitRev: 2e1f913d3ca3)
# For execution on a local, multicore CPU with excess RAM we recommend calling
# options(mc.cores = parallel::detectCores()).
# To avoid recompilation of unchanged Stan programs, we recommend calling
# rstan_options(auto_write = TRUE)
#
# Attaching package: ‘rstan’
#
# The following object is masked from ‘package:tidyr’:
#
#     extract
#
# here() starts at /Users/russellsteele/Dropbox/0 New GTD folder/Projects/NSERC Bayes Optimization/NYU_talk

# %%
rstan_options(auto_write = TRUE)
options(mc.cores = parallel::detectCores())

# %%
mag_code = "
        data {
        int<lower=0> J; // number of studies
        int<lower=0> Y_m[J];
        int<lower=0> Y_c[J]; // Deaths in both groups
        int<lower=0> N_m[J];
        int<lower=0> N_c[J]; //Total subjects in both groups
        real<lower=0> eta; // Prior sd of mu
        real<lower=0> s; //scaling parameter for prior for tau
        }

        parameters {
            real delta[J]; // log odds ratios
            real<lower=0,upper=1> q[J];  // baseline probability
            real<lower=0> tau; // standard deviation of random effets
            real mu; // 
        }

        transformed parameters {
            real<lower=0,upper=1> p[J];
            real phi[J]; 
            for (j in 1:J){
                phi[j] = logit(q[j]);  // Invert Binomial probs for control
                p[j] = inv_logit(delta[j] + phi[j]); // Binomial probs for response
            }
        }

        model {
            Y_m ~ binomial(N_m,p);
            Y_c ~ binomial(N_c,q);
            delta ~ normal(mu,tau);
            q ~ uniform(0,1);
            tau ~ cauchy(0, s);
            mu ~ normal(0,eta);
        }

        generated quantities { 
        real medianOR; 
        medianOR = exp(mu);
        }
        "

# %%
magnes_data=read.dta(here("data/magnes.dta"))
magnes_data_noSch1 = magnes_data %>% filter(trialnam!="Schechter 1") %>% 
  mutate(Study=paste(trialnam,year," ")) %>%
  rename(Year=year,N_m = tot1,N_c=tot0,Y_m=dead1,Y_c=dead0) %>% 
  mutate(p_m=Y_m/N_m,p_c=Y_c/N_c,Beneficial=factor(ifelse(p_m>=p_c,"Harmful","Beneficial")),
         #TotalSize = cut(x=N_m+N_c,breaks=c(0,50,250,1000,2500,5000,25000,60000)))
          TotalSize=N_m+N_c)
#magnes_data_noSch1  %>%  select(Study,N_m:Y_c)%>%kable(.)
# Out:
# Warning message:
# “package ‘bindrcpp’ was built under R version 3.4.4”

# %%
data_list = with(magnes_data_noSch1, 
                 list(J=nrow(magnes_data_noSch1), 
                      Y_m = Y_m,
                      Y_c = Y_c,
                      N_m = N_m,
                      N_c = N_c,
                      s = 1,
                      eta=NULL)
                     )

# %%
data_list[["eta"]] = 0.7
stan_samples_0.7 <- stan(model_code = mag_code, data = data_list,verbose=T)
# Out:
# TRANSLATING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' FROM Stan CODE TO C++ CODE NOW.
# successful in parsing the Stan model 'be8ceb788a44a6e7bcdeb561d91170b7'.
#
# CHECKING DATA AND PREPROCESSING FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# COMPILING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# STARTING SAMPLER FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.

# %%
print(stan_samples_0.7,pars=c("tau","mu","medianOR"))
# Out:
# Inference for Stan model: be8ceb788a44a6e7bcdeb561d91170b7.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#           mean se_mean   sd  2.5%   25%   50%   75% 97.5% n_eff Rhat
# tau       0.64    0.01 0.21  0.31  0.49  0.60  0.75  1.15  1398    1
# mu       -0.80    0.00 0.23 -1.27 -0.95 -0.79 -0.64 -0.36  2439    1
# medianOR  0.46    0.00 0.11  0.28  0.39  0.45  0.53  0.70  2463    1
#
# Samples were drawn using NUTS(diag_e) at Wed Nov 28 15:57:30 2018.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
data_list[["eta"]] = 0.4
stan_samples_0.4 <- stan(model_code = mag_code, data = data_list,verbose=T)
# Out:
# TRANSLATING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' FROM Stan CODE TO C++ CODE NOW.
# successful in parsing the Stan model 'be8ceb788a44a6e7bcdeb561d91170b7'.
#
# CHECKING DATA AND PREPROCESSING FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# COMPILING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# STARTING SAMPLER FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
# Warning message:
# “There were 1 divergent transitions after warmup. Increasing adapt_delta above 0.8 may help. See
# http://mc-stan.org/misc/warnings.html#divergent-transitions-after-warmup”Warning message:
# “Examine the pairs() plot to diagnose sampling problems
# ”

# %%
print(stan_samples_0.4,pars=c("tau","mu","medianOR"))
# Out:
# Inference for Stan model: be8ceb788a44a6e7bcdeb561d91170b7.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#           mean se_mean   sd  2.5%   25%   50%   75% 97.5% n_eff Rhat
# tau       0.60    0.01 0.22  0.27  0.45  0.57  0.71  1.10  1463    1
# mu       -0.66    0.00 0.20 -1.05 -0.79 -0.65 -0.52 -0.27  3252    1
# medianOR  0.53    0.00 0.11  0.35  0.46  0.52  0.59  0.77  3188    1
#
# Samples were drawn using NUTS(diag_e) at Wed Nov 28 16:13:11 2018.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
data_list[["eta"]] = 0.1
stan_samples_0.1 <- stan(model_code = mag_code, data = data_list,verbose=T)
# Out:
# TRANSLATING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' FROM Stan CODE TO C++ CODE NOW.
# successful in parsing the Stan model 'be8ceb788a44a6e7bcdeb561d91170b7'.
#
# CHECKING DATA AND PREPROCESSING FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# COMPILING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# STARTING SAMPLER FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.

# %%
print(stan_samples_0.1,pars=c("tau","mu","medianOR"))
# Out:
# Inference for Stan model: be8ceb788a44a6e7bcdeb561d91170b7.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#           mean se_mean   sd  2.5%   25%   50%   75% 97.5% n_eff Rhat
# tau       0.89    0.01 0.34  0.32  0.65  0.86  1.10  1.66  1368    1
# mu       -0.11    0.00 0.10 -0.31 -0.19 -0.11 -0.04  0.08  4000    1
# medianOR  0.90    0.00 0.09  0.73  0.83  0.89  0.96  1.09  4000    1
#
# Samples were drawn using NUTS(diag_e) at Wed Nov 28 16:14:07 2018.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
print(eval(as.name(paste("stan_samples_",0.1,sep=""))),pars=c("tau","mu","medianOR"))
# Out:
# Inference for Stan model: be8ceb788a44a6e7bcdeb561d91170b7.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#           mean se_mean   sd  2.5%   25%   50%   75% 97.5% n_eff Rhat
# tau       0.89    0.01 0.34  0.32  0.65  0.86  1.10  1.66  1368    1
# mu       -0.11    0.00 0.10 -0.31 -0.19 -0.11 -0.04  0.08  4000    1
# medianOR  0.90    0.00 0.09  0.73  0.83  0.89  0.96  1.09  4000    1
#
# Samples were drawn using NUTS(diag_e) at Wed Nov 28 16:14:07 2018.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
one_stan_out = function(x){ 
    data_frame(medianOR=rstan::extract(eval(as.name(paste("stan_samples_",x,sep=""))),
                                       par="medianOR")$medianOR, 
               eta = x)
               
}

# %%
my_output_df = c("0.1","0.4","0.7") %>% map_df(~one_stan_out(.))
# Out:
# Error in eval(as.name(paste("stan_samples_", x, sep = ""))): object 'stan_samples_0.1' not found
# Traceback:
#
# 1. c("0.1", "0.4", "0.7") %>% map_df(~one_stan_out(.))
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. map_df(., ~one_stan_out(.))
# 10. map(.x, .f, ...)
# 11. .f(.x[[i]], ...)
# 12. one_stan_out(.)
# 13. data_frame(medianOR = rstan::extract(eval(as.name(paste("stan_samples_",
#   .     x, sep = ""))), par = "medianOR")$medianOR, eta = x)   # at line 2-4 of file <text>
# 14. as_tibble(lst_quos(xs, expand = TRUE))
# 15. lst_quos(xs, expand = TRUE)
# 16. eval_tidy(xs[[i]], unique_output)
# 17. rstan::extract(eval(as.name(paste("stan_samples_", x, sep = ""))),
#   .     par = "medianOR")
# 18. eval(as.name(paste("stan_samples_", x, sep = "")))
# 19. eval(as.name(paste("stan_samples_", x, sep = "")))

# %%
write_csv(my_output_df,here("results/stan_out_147.csv"))

# %%
data_list[["eta"]] = 1.0
stan_samples_1.0 <- stan(model_code = mag_code, data = data_list,verbose=T)
# Out:
# TRANSLATING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' FROM Stan CODE TO C++ CODE NOW.
# successful in parsing the Stan model 'be8ceb788a44a6e7bcdeb561d91170b7'.
# OS: x86_64, darwin15.6.0; rstan: 2.17.3; Rcpp: 0.12.18; inline: 0.3.14
#  >> setting environment variables:
# PKG_LIBS =  -L'/Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/lib' -lStanHeaders
# PKG_CPPFLAGS =   -I"/Library/Frameworks/R.framework/Versions/3.4/Resources/library/Rcpp/include/"  -I"/Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/"  -I"/Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/unsupported"  -I"/Library/Frameworks/R.framework/Versions/3.4/Resources/library/rstan/include/boost_not_in_BH" -I"/Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include" -I"/Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/"  -I"/Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/"  -I"/Library/Frameworks/R.framework/Versions/3.4/Resources/library/rstan/include" -DEIGEN_NO_DEBUG  -DBOOST_RESULT_OF_USE_TR1 -DBOOST_NO_DECLTYPE -DBOOST_DISABLE_ASSERTS -DBOOST_NO_CXX11_RVALUE_REFERENCES
#  >> Program source :
#
#    1 :
#    2 : // includes from the plugin
#    3 :
#    4 :
#    5 : // user includes
#    6 : #define STAN__SERVICES__COMMAND_HPP// Code generated by Stan version 2.17.0
#    7 :
#    8 : #include <stan/model/model_header.hpp>
#    9 :
#   10 : namespace model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace {
#   11 :
#   12 : using std::istream;
#   13 : using std::string;
#   14 : using std::stringstream;
#   15 : using std::vector;
#   16 : using stan::io::dump;
#   17 : using stan::math::lgamma;
#   18 : using stan::model::prob_grad;
#   19 : using namespace stan::math;
#   20 :
#   21 : typedef Eigen::Matrix<double,Eigen::Dynamic,1> vector_d;
#   22 : typedef Eigen::Matrix<double,1,Eigen::Dynamic> row_vector_d;
#   23 : typedef Eigen::Matrix<double,Eigen::Dynamic,Eigen::Dynamic> matrix_d;
#   24 :
#   25 : static int current_statement_begin__;
#   26 :
#   27 : stan::io::program_reader prog_reader__() {
#   28 :     stan::io::program_reader reader;
#   29 :     reader.add_event(0, 0, "start", "model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7");
#   30 :     reader.add_event(41, 41, "end", "model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7");
#   31 :     return reader;
#   32 : }
#   33 :
#   34 : class model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7 : public prob_grad {
#   35 : private:
#   36 :     int J;
#   37 :     vector<int> Y_m;
#   38 :     vector<int> Y_c;
#   39 :     vector<int> N_m;
#   40 :     vector<int> N_c;
#   41 :     double eta;
#   42 :     double s;
#   43 : public:
#   44 :     model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7(stan::io::var_context& context__,
#   45 :         std::ostream* pstream__ = 0)
#   46 :         : prob_grad(0) {
#   47 :         ctor_body(context__, 0, pstream__);
#   48 :     }
#   49 :
#   50 :     model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7(stan::io::var_context& context__,
#   51 :         unsigned int random_seed__,
#   52 :         std::ostream* pstream__ = 0)
#   53 :         : prob_grad(0) {
#   54 :         ctor_body(context__, random_seed__, pstream__);
#   55 :     }
#   56 :
#   57 :     void ctor_body(stan::io::var_context& context__,
#   58 :                    unsigned int random_seed__,
#   59 :                    std::ostream* pstream__) {
#   60 :         boost::ecuyer1988 base_rng__ =
#   61 :           stan::services::util::create_rng(random_seed__, 0);
#   62 :         (void) base_rng__;  // suppress unused var warning
#   63 :
#   64 :         current_statement_begin__ = -1;
#   65 :
#   66 :         static const char* function__ = "model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7";
#   67 :         (void) function__;  // dummy to suppress unused var warning
#   68 :         size_t pos__;
#   69 :         (void) pos__;  // dummy to suppress unused var warning
#   70 :         std::vector<int> vals_i__;
#   71 :         std::vector<double> vals_r__;
#   72 :         double DUMMY_VAR__(std::numeric_limits<double>::quiet_NaN());
#   73 :         (void) DUMMY_VAR__;  // suppress unused var warning
#   74 :
#   75 :         // initialize member variables
#   76 :         try {
#   77 :             current_statement_begin__ = 3;
#   78 :             context__.validate_dims("data initialization", "J", "int", context__.to_vec());
#   79 :             J = int(0);
#   80 :             vals_i__ = context__.vals_i("J");
#   81 :             pos__ = 0;
#   82 :             J = vals_i__[pos__++];
#   83 :             current_statement_begin__ = 4;
#   84 :             validate_non_negative_index("Y_m", "J", J);
#   85 :             context__.validate_dims("data initialization", "Y_m", "int", context__.to_vec(J));
#   86 :             validate_non_negative_index("Y_m", "J", J);
#   87 :             Y_m = std::vector<int>(J,int(0));
#   88 :             vals_i__ = context__.vals_i("Y_m");
#   89 :             pos__ = 0;
#   90 :             size_t Y_m_limit_0__ = J;
#   91 :             for (size_t i_0__ = 0; i_0__ < Y_m_limit_0__; ++i_0__) {
#   92 :                 Y_m[i_0__] = vals_i__[pos__++];
#   93 :             }
#   94 :             current_statement_begin__ = 5;
#   95 :             validate_non_negative_index("Y_c", "J", J);
#   96 :             context__.validate_dims("data initialization", "Y_c", "int", context__.to_vec(J));
#   97 :             validate_non_negative_index("Y_c", "J", J);
#   98 :             Y_c = std::vector<int>(J,int(0));
#   99 :             vals_i__ = context__.vals_i("Y_c");
#  100 :             pos__ = 0;
#  101 :             size_t Y_c_limit_0__ = J;
#  102 :             for (size_t i_0__ = 0; i_0__ < Y_c_limit_0__; ++i_0__) {
#  103 :                 Y_c[i_0__] = vals_i__[pos__++];
#  104 :             }
#  105 :             current_statement_begin__ = 6;
#  106 :             validate_non_negative_index("N_m", "J", J);
#  107 :             context__.validate_dims("data initialization", "N_m", "int", context__.to_vec(J));
#  108 :             validate_non_negative_index("N_m", "J", J);
#  109 :             N_m = std::vector<int>(J,int(0));
#  110 :             vals_i__ = context__.vals_i("N_m");
#  111 :             pos__ = 0;
#  112 :             size_t N_m_limit_0__ = J;
#  113 :             for (size_t i_0__ = 0; i_0__ < N_m_limit_0__; ++i_0__) {
#  114 :                 N_m[i_0__] = vals_i__[pos__++];
#  115 :             }
#  116 :             current_statement_begin__ = 7;
#  117 :             validate_non_negative_index("N_c", "J", J);
#  118 :             context__.validate_dims("data initialization", "N_c", "int", context__.to_vec(J));
#  119 :             validate_non_negative_index("N_c", "J", J);
#  120 :             N_c = std::vector<int>(J,int(0));
#  121 :             vals_i__ = context__.vals_i("N_c");
#  122 :             pos__ = 0;
#  123 :             size_t N_c_limit_0__ = J;
#  124 :             for (size_t i_0__ = 0; i_0__ < N_c_limit_0__; ++i_0__) {
#  125 :                 N_c[i_0__] = vals_i__[pos__++];
#  126 :             }
#  127 :             current_statement_begin__ = 8;
#  128 :             context__.validate_dims("data initialization", "eta", "double", context__.to_vec());
#  129 :             eta = double(0);
#  130 :             vals_r__ = context__.vals_r("eta");
#  131 :             pos__ = 0;
#  132 :             eta = vals_r__[pos__++];
#  133 :             current_statement_begin__ = 9;
#  134 :             context__.validate_dims("data initialization", "s", "double", context__.to_vec());
#  135 :             s = double(0);
#  136 :             vals_r__ = context__.vals_r("s");
#  137 :             pos__ = 0;
#  138 :             s = vals_r__[pos__++];
#  139 :
#  140 :             // validate, data variables
#  141 :             current_statement_begin__ = 3;
#  142 :             check_greater_or_equal(function__,"J",J,0);
#  143 :             current_statement_begin__ = 4;
#  144 :             for (int k0__ = 0; k0__ < J; ++k0__) {
#  145 :                 check_greater_or_equal(function__,"Y_m[k0__]",Y_m[k0__],0);
#  146 :             }
#  147 :             current_statement_begin__ = 5;
#  148 :             for (int k0__ = 0; k0__ < J; ++k0__) {
#  149 :                 check_greater_or_equal(function__,"Y_c[k0__]",Y_c[k0__],0);
#  150 :             }
#  151 :             current_statement_begin__ = 6;
#  152 :             for (int k0__ = 0; k0__ < J; ++k0__) {
#  153 :                 check_greater_or_equal(function__,"N_m[k0__]",N_m[k0__],0);
#  154 :             }
#  155 :             current_statement_begin__ = 7;
#  156 :             for (int k0__ = 0; k0__ < J; ++k0__) {
#  157 :                 check_greater_or_equal(function__,"N_c[k0__]",N_c[k0__],0);
#  158 :             }
#  159 :             current_statement_begin__ = 8;
#  160 :             check_greater_or_equal(function__,"eta",eta,0);
#  161 :             current_statement_begin__ = 9;
#  162 :             check_greater_or_equal(function__,"s",s,0);
#  163 :             // initialize data variables
#  164 :
#  165 :
#  166 :             // validate transformed data
#  167 :
#  168 :             // validate, set parameter ranges
#  169 :             num_params_r__ = 0U;
#  170 :             param_ranges_i__.clear();
#  171 :             current_statement_begin__ = 13;
#  172 :             validate_non_negative_index("delta", "J", J);
#  173 :             num_params_r__ += J;
#  174 :             current_statement_begin__ = 14;
#  175 :             validate_non_negative_index("q", "J", J);
#  176 :             num_params_r__ += J;
#  177 :             current_statement_begin__ = 15;
#  178 :             ++num_params_r__;
#  179 :             current_statement_begin__ = 16;
#  180 :             ++num_params_r__;
#  181 :         } catch (const std::exception& e) {
#  182 :             stan::lang::rethrow_located(e, current_statement_begin__, prog_reader__());
#  183 :             // Next line prevents compiler griping about no return
#  184 :             throw std::runtime_error("*** IF YOU SEE THIS, PLEASE REPORT A BUG ***");
#  185 :         }
#  186 :     }
#  187 :
#  188 :     ~model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7() { }
#  189 :
#  190 :
#  191 :     void transform_inits(const stan::io::var_context& context__,
#  192 :                          std::vector<int>& params_i__,
#  193 :                          std::vector<double>& params_r__,
#  194 :                          std::ostream* pstream__) const {
#  195 :         stan::io::writer<double> writer__(params_r__,params_i__);
#  196 :         size_t pos__;
#  197 :         (void) pos__; // dummy call to supress warning
#  198 :         std::vector<double> vals_r__;
#  199 :         std::vector<int> vals_i__;
#  200 :
#  201 :         if (!(context__.contains_r("delta")))
#  202 :             throw std::runtime_error("variable delta missing");
#  203 :         vals_r__ = context__.vals_r("delta");
#  204 :         pos__ = 0U;
#  205 :         validate_non_negative_index("delta", "J", J);
#  206 :         context__.validate_dims("initialization", "delta", "double", context__.to_vec(J));
#  207 :         std::vector<double> delta(J,double(0));
#  208 :         for (int i0__ = 0U; i0__ < J; ++i0__)
#  209 :             delta[i0__] = vals_r__[pos__++];
#  210 :         for (int i0__ = 0U; i0__ < J; ++i0__)
#  211 :             try {
#  212 :             writer__.scalar_unconstrain(delta[i0__]);
#  213 :         } catch (const std::exception& e) {
#  214 :             throw std::runtime_error(std::string("Error transforming variable delta: ") + e.what());
#  215 :         }
#  216 :
#  217 :         if (!(context__.contains_r("q")))
#  218 :             throw std::runtime_error("variable q missing");
#  219 :         vals_r__ = context__.vals_r("q");
#  220 :         pos__ = 0U;
#  221 :         validate_non_negative_index("q", "J", J);
#  222 :         context__.validate_dims("initialization", "q", "double", context__.to_vec(J));
#  223 :         std::vector<double> q(J,double(0));
#  224 :         for (int i0__ = 0U; i0__ < J; ++i0__)
#  225 :             q[i0__] = vals_r__[pos__++];
#  226 :         for (int i0__ = 0U; i0__ < J; ++i0__)
#  227 :             try {
#  228 :             writer__.scalar_lub_unconstrain(0,1,q[i0__]);
#  229 :         } catch (const std::exception& e) {
#  230 :             throw std::runtime_error(std::string("Error transforming variable q: ") + e.what());
#  231 :         }
#  232 :
#  233 :         if (!(context__.contains_r("tau")))
#  234 :             throw std::runtime_error("variable tau missing");
#  235 :         vals_r__ = context__.vals_r("tau");
#  236 :         pos__ = 0U;
#  237 :         context__.validate_dims("initialization", "tau", "double", context__.to_vec());
#  238 :         double tau(0);
#  239 :         tau = vals_r__[pos__++];
#  240 :         try {
#  241 :             writer__.scalar_lb_unconstrain(0,tau);
#  242 :         } catch (const std::exception& e) {
#  243 :             throw std::runtime_error(std::string("Error transforming variable tau: ") + e.what());
#  244 :         }
#  245 :
#  246 :         if (!(context__.contains_r("mu")))
#  247 :             throw std::runtime_error("variable mu missing");
#  248 :         vals_r__ = context__.vals_r("mu");
#  249 :         pos__ = 0U;
#  250 :         context__.validate_dims("initialization", "mu", "double", context__.to_vec());
#  251 :         double mu(0);
#  252 :         mu = vals_r__[pos__++];
#  253 :         try {
#  254 :             writer__.scalar_unconstrain(mu);
#  255 :         } catch (const std::exception& e) {
#  256 :             throw std::runtime_error(std::string("Error transforming variable mu: ") + e.what());
#  257 :         }
#  258 :
#  259 :         params_r__ = writer__.data_r();
#  260 :         params_i__ = writer__.data_i();
#  261 :     }
#  262 :
#  263 :     void transform_inits(const stan::io::var_context& context,
#  264 :                          Eigen::Matrix<double,Eigen::Dynamic,1>& params_r,
#  265 :                          std::ostream* pstream__) const {
#  266 :       std::vector<double> params_r_vec;
#  267 :       std::vector<int> params_i_vec;
#  268 :       transform_inits(context, params_i_vec, params_r_vec, pstream__);
#  269 :       params_r.resize(params_r_vec.size());
#  270 :       for (int i = 0; i < params_r.size(); ++i)
#  271 :         params_r(i) = params_r_vec[i];
#  272 :     }
#  273 :
#  274 :
#  275 :     template <bool propto__, bool jacobian__, typename T__>
#  276 :     T__ log_prob(vector<T__>& params_r__,
#  277 :                  vector<int>& params_i__,
#  278 :                  std::ostream* pstream__ = 0) const {
#  279 :
#  280 :         T__ DUMMY_VAR__(std::numeric_limits<double>::quiet_NaN());
#  281 :         (void) DUMMY_VAR__;  // suppress unused var warning
#  282 :
#  283 :         T__ lp__(0.0);
#  284 :         stan::math::accumulator<T__> lp_accum__;
#  285 :
#  286 :         try {
#  287 :             // model parameters
#  288 :             stan::io::reader<T__> in__(params_r__,params_i__);
#  289 :
#  290 :             vector<T__> delta;
#  291 :             size_t dim_delta_0__ = J;
#  292 :             delta.reserve(dim_delta_0__);
#  293 :             for (size_t k_0__ = 0; k_0__ < dim_delta_0__; ++k_0__) {
#  294 :                 if (jacobian__)
#  295 :                     delta.push_back(in__.scalar_constrain(lp__));
#  296 :                 else
#  297 :                     delta.push_back(in__.scalar_constrain());
#  298 :             }
#  299 :
#  300 :             vector<T__> q;
#  301 :             size_t dim_q_0__ = J;
#  302 :             q.reserve(dim_q_0__);
#  303 :             for (size_t k_0__ = 0; k_0__ < dim_q_0__; ++k_0__) {
#  304 :                 if (jacobian__)
#  305 :                     q.push_back(in__.scalar_lub_constrain(0,1,lp__));
#  306 :                 else
#  307 :                     q.push_back(in__.scalar_lub_constrain(0,1));
#  308 :             }
#  309 :
#  310 :             T__ tau;
#  311 :             (void) tau;  // dummy to suppress unused var warning
#  312 :             if (jacobian__)
#  313 :                 tau = in__.scalar_lb_constrain(0,lp__);
#  314 :             else
#  315 :                 tau = in__.scalar_lb_constrain(0);
#  316 :
#  317 :             T__ mu;
#  318 :             (void) mu;  // dummy to suppress unused var warning
#  319 :             if (jacobian__)
#  320 :                 mu = in__.scalar_constrain(lp__);
#  321 :             else
#  322 :                 mu = in__.scalar_constrain();
#  323 :
#  324 :
#  325 :             // transformed parameters
#  326 :             current_statement_begin__ = 20;
#  327 :             validate_non_negative_index("p", "J", J);
#  328 :             vector<T__> p(J);
#  329 :             stan::math::initialize(p, DUMMY_VAR__);
#  330 :             stan::math::fill(p,DUMMY_VAR__);
#  331 :             current_statement_begin__ = 21;
#  332 :             validate_non_negative_index("phi", "J", J);
#  333 :             vector<T__> phi(J);
#  334 :             stan::math::initialize(phi, DUMMY_VAR__);
#  335 :             stan::math::fill(phi,DUMMY_VAR__);
#  336 :
#  337 :
#  338 :             current_statement_begin__ = 22;
#  339 :             for (int j = 1; j <= J; ++j) {
#  340 :
#  341 :                 current_statement_begin__ = 23;
#  342 :                 stan::math::assign(get_base1_lhs(phi,j,"phi",1), logit(get_base1(q,j,"q",1)));
#  343 :                 current_statement_begin__ = 24;
#  344 :                 stan::math::assign(get_base1_lhs(p,j,"p",1), inv_logit((get_base1(delta,j,"delta",1) + get_base1(phi,j,"phi",1))));
#  345 :             }
#  346 :
#  347 :             // validate transformed parameters
#  348 :             for (int i0__ = 0; i0__ < J; ++i0__) {
#  349 :                 if (stan::math::is_uninitialized(p[i0__])) {
#  350 :                     std::stringstream msg__;
#  351 :                     msg__ << "Undefined transformed parameter: p" << '[' << i0__ << ']';
#  352 :                     throw std::runtime_error(msg__.str());
#  353 :                 }
#  354 :             }
#  355 :             for (int i0__ = 0; i0__ < J; ++i0__) {
#  356 :                 if (stan::math::is_uninitialized(phi[i0__])) {
#  357 :                     std::stringstream msg__;
#  358 :                     msg__ << "Undefined transformed parameter: phi" << '[' << i0__ << ']';
#  359 :                     throw std::runtime_error(msg__.str());
#  360 :                 }
#  361 :             }
#  362 :
#  363 :             const char* function__ = "validate transformed params";
#  364 :             (void) function__;  // dummy to suppress unused var warning
#  365 :             current_statement_begin__ = 20;
#  366 :             for (int k0__ = 0; k0__ < J; ++k0__) {
#  367 :                 check_greater_or_equal(function__,"p[k0__]",p[k0__],0);
#  368 :                 check_less_or_equal(function__,"p[k0__]",p[k0__],1);
#  369 :             }
#  370 :             current_statement_begin__ = 21;
#  371 :
#  372 :             // model body
#  373 :
#  374 :             current_statement_begin__ = 29;
#  375 :             lp_accum__.add(binomial_log<propto__>(Y_m, N_m, p));
#  376 :             current_statement_begin__ = 30;
#  377 :             lp_accum__.add(binomial_log<propto__>(Y_c, N_c, q));
#  378 :             current_statement_begin__ = 31;
#  379 :             lp_accum__.add(normal_log<propto__>(delta, mu, tau));
#  380 :             current_statement_begin__ = 32;
#  381 :             lp_accum__.add(uniform_log<propto__>(q, 0, 1));
#  382 :             current_statement_begin__ = 33;
#  383 :             lp_accum__.add(cauchy_log<propto__>(tau, 0, s));
#  384 :             current_statement_begin__ = 34;
#  385 :             lp_accum__.add(normal_log<propto__>(mu, 0, eta));
#  386 :
#  387 :         } catch (const std::exception& e) {
#  388 :             stan::lang::rethrow_located(e, current_statement_begin__, prog_reader__());
#  389 :             // Next line prevents compiler griping about no return
#  390 :             throw std::runtime_error("*** IF YOU SEE THIS, PLEASE REPORT A BUG ***");
#  391 :         }
#  392 :
#  393 :         lp_accum__.add(lp__);
#  394 :         return lp_accum__.sum();
#  395 :
#  396 :     } // log_prob()
#  397 :
#  398 :     template <bool propto, bool jacobian, typename T_>
#  399 :     T_ log_prob(Eigen::Matrix<T_,Eigen::Dynamic,1>& params_r,
#  400 :                std::ostream* pstream = 0) const {
#  401 :       std::vector<T_> vec_params_r;
#  402 :       vec_params_r.reserve(params_r.size());
#  403 :       for (int i = 0; i < params_r.size(); ++i)
#  404 :         vec_params_r.push_back(params_r(i));
#  405 :       std::vector<int> vec_params_i;
#  406 :       return log_prob<propto,jacobian,T_>(vec_params_r, vec_params_i, pstream);
#  407 :     }
#  408 :
#  409 :
#  410 :     void get_param_names(std::vector<std::string>& names__) const {
#  411 :         names__.resize(0);
#  412 :         names__.push_back("delta");
#  413 :         names__.push_back("q");
#  414 :         names__.push_back("tau");
#  415 :         names__.push_back("mu");
#  416 :         names__.push_back("p");
#  417 :         names__.push_back("phi");
#  418 :         names__.push_back("medianOR");
#  419 :     }
#  420 :
#  421 :
#  422 :     void get_dims(std::vector<std::vector<size_t> >& dimss__) const {
#  423 :         dimss__.resize(0);
#  424 :         std::vector<size_t> dims__;
#  425 :         dims__.resize(0);
#  426 :         dims__.push_back(J);
#  427 :         dimss__.push_back(dims__);
#  428 :         dims__.resize(0);
#  429 :         dims__.push_back(J);
#  430 :         dimss__.push_back(dims__);
#  431 :         dims__.resize(0);
#  432 :         dimss__.push_back(dims__);
#  433 :         dims__.resize(0);
#  434 :         dimss__.push_back(dims__);
#  435 :         dims__.resize(0);
#  436 :         dims__.push_back(J);
#  437 :         dimss__.push_back(dims__);
#  438 :         dims__.resize(0);
#  439 :         dims__.push_back(J);
#  440 :         dimss__.push_back(dims__);
#  441 :         dims__.resize(0);
#  442 :         dimss__.push_back(dims__);
#  443 :     }
#  444 :
#  445 :     template <typename RNG>
#  446 :     void write_array(RNG& base_rng__,
#  447 :                      std::vector<double>& params_r__,
#  448 :                      std::vector<int>& params_i__,
#  449 :                      std::vector<double>& vars__,
#  450 :                      bool include_tparams__ = true,
#  451 :                      bool include_gqs__ = true,
#  452 :                      std::ostream* pstream__ = 0) const {
#  453 :         vars__.resize(0);
#  454 :         stan::io::reader<double> in__(params_r__,params_i__);
#  455 :         static const char* function__ = "model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::write_array";
#  456 :         (void) function__;  // dummy to suppress unused var warning
#  457 :         // read-transform, write parameters
#  458 :         vector<double> delta;
#  459 :         size_t dim_delta_0__ = J;
#  460 :         for (size_t k_0__ = 0; k_0__ < dim_delta_0__; ++k_0__) {
#  461 :             delta.push_back(in__.scalar_constrain());
#  462 :         }
#  463 :         vector<double> q;
#  464 :         size_t dim_q_0__ = J;
#  465 :         for (size_t k_0__ = 0; k_0__ < dim_q_0__; ++k_0__) {
#  466 :             q.push_back(in__.scalar_lub_constrain(0,1));
#  467 :         }
#  468 :         double tau = in__.scalar_lb_constrain(0);
#  469 :         double mu = in__.scalar_constrain();
#  470 :             for (int k_0__ = 0; k_0__ < J; ++k_0__) {
#  471 :             vars__.push_back(delta[k_0__]);
#  472 :             }
#  473 :             for (int k_0__ = 0; k_0__ < J; ++k_0__) {
#  474 :             vars__.push_back(q[k_0__]);
#  475 :             }
#  476 :         vars__.push_back(tau);
#  477 :         vars__.push_back(mu);
#  478 :
#  479 :         if (!include_tparams__) return;
#  480 :         // declare and define transformed parameters
#  481 :         double lp__ = 0.0;
#  482 :         (void) lp__;  // dummy to suppress unused var warning
#  483 :         stan::math::accumulator<double> lp_accum__;
#  484 :
#  485 :         double DUMMY_VAR__(std::numeric_limits<double>::quiet_NaN());
#  486 :         (void) DUMMY_VAR__;  // suppress unused var warning
#  487 :
#  488 :         try {
#  489 :             current_statement_begin__ = 20;
#  490 :             validate_non_negative_index("p", "J", J);
#  491 :             vector<double> p(J, 0.0);
#  492 :             stan::math::initialize(p, std::numeric_limits<double>::quiet_NaN());
#  493 :             stan::math::fill(p,DUMMY_VAR__);
#  494 :             current_statement_begin__ = 21;
#  495 :             validate_non_negative_index("phi", "J", J);
#  496 :             vector<double> phi(J, 0.0);
#  497 :             stan::math::initialize(phi, std::numeric_limits<double>::quiet_NaN());
#  498 :             stan::math::fill(phi,DUMMY_VAR__);
#  499 :
#  500 :
#  501 :             current_statement_begin__ = 22;
#  502 :             for (int j = 1; j <= J; ++j) {
#  503 :
#  504 :                 current_statement_begin__ = 23;
#  505 :                 stan::math::assign(get_base1_lhs(phi,j,"phi",1), logit(get_base1(q,j,"q",1)));
#  506 :                 current_statement_begin__ = 24;
#  507 :                 stan::math::assign(get_base1_lhs(p,j,"p",1), inv_logit((get_base1(delta,j,"delta",1) + get_base1(phi,j,"phi",1))));
#  508 :             }
#  509 :
#  510 :             // validate transformed parameters
#  511 :             current_statement_begin__ = 20;
#  512 :             for (int k0__ = 0; k0__ < J; ++k0__) {
#  513 :                 check_greater_or_equal(function__,"p[k0__]",p[k0__],0);
#  514 :                 check_less_or_equal(function__,"p[k0__]",p[k0__],1);
#  515 :             }
#  516 :             current_statement_begin__ = 21;
#  517 :
#  518 :             // write transformed parameters
#  519 :             for (int k_0__ = 0; k_0__ < J; ++k_0__) {
#  520 :             vars__.push_back(p[k_0__]);
#  521 :             }
#  522 :             for (int k_0__ = 0; k_0__ < J; ++k_0__) {
#  523 :             vars__.push_back(phi[k_0__]);
#  524 :             }
#  525 :
#  526 :             if (!include_gqs__) return;
#  527 :             // declare and define generated quantities
#  528 :             current_statement_begin__ = 38;
#  529 :             double medianOR(0.0);
#  530 :             (void) medianOR;  // dummy to suppress unused var warning
#  531 :
#  532 :             stan::math::initialize(medianOR, std::numeric_limits<double>::quiet_NaN());
#  533 :             stan::math::fill(medianOR,DUMMY_VAR__);
#  534 :
#  535 :
#  536 :             current_statement_begin__ = 39;
#  537 :             stan::math::assign(medianOR, exp(mu));
#  538 :
#  539 :             // validate generated quantities
#  540 :             current_statement_begin__ = 38;
#  541 :
#  542 :             // write generated quantities
#  543 :         vars__.push_back(medianOR);
#  544 :
#  545 :         } catch (const std::exception& e) {
#  546 :             stan::lang::rethrow_located(e, current_statement_begin__, prog_reader__());
#  547 :             // Next line prevents compiler griping about no return
#  548 :             throw std::runtime_error("*** IF YOU SEE THIS, PLEASE REPORT A BUG ***");
#  549 :         }
#  550 :     }
#  551 :
#  552 :     template <typename RNG>
#  553 :     void write_array(RNG& base_rng,
#  554 :                      Eigen::Matrix<double,Eigen::Dynamic,1>& params_r,
#  555 :                      Eigen::Matrix<double,Eigen::Dynamic,1>& vars,
#  556 :                      bool include_tparams = true,
#  557 :                      bool include_gqs = true,
#  558 :                      std::ostream* pstream = 0) const {
#  559 :       std::vector<double> params_r_vec(params_r.size());
#  560 :       for (int i = 0; i < params_r.size(); ++i)
#  561 :         params_r_vec[i] = params_r(i);
#  562 :       std::vector<double> vars_vec;
#  563 :       std::vector<int> params_i_vec;
#  564 :       write_array(base_rng,params_r_vec,params_i_vec,vars_vec,include_tparams,include_gqs,pstream);
#  565 :       vars.resize(vars_vec.size());
#  566 :       for (int i = 0; i < vars.size(); ++i)
#  567 :         vars(i) = vars_vec[i];
#  568 :     }
#  569 :
#  570 :     static std::string model_name() {
#  571 :         return "model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7";
#  572 :     }
#  573 :
#  574 :
#  575 :     void constrained_param_names(std::vector<std::string>& param_names__,
#  576 :                                  bool include_tparams__ = true,
#  577 :                                  bool include_gqs__ = true) const {
#  578 :         std::stringstream param_name_stream__;
#  579 :         for (int k_0__ = 1; k_0__ <= J; ++k_0__) {
#  580 :             param_name_stream__.str(std::string());
#  581 :             param_name_stream__ << "delta" << '.' << k_0__;
#  582 :             param_names__.push_back(param_name_stream__.str());
#  583 :         }
#  584 :         for (int k_0__ = 1; k_0__ <= J; ++k_0__) {
#  585 :             param_name_stream__.str(std::string());
#  586 :             param_name_stream__ << "q" << '.' << k_0__;
#  587 :             param_names__.push_back(param_name_stream__.str());
#  588 :         }
#  589 :         param_name_stream__.str(std::string());
#  590 :         param_name_stream__ << "tau";
#  591 :         param_names__.push_back(param_name_stream__.str());
#  592 :         param_name_stream__.str(std::string());
#  593 :         param_name_stream__ << "mu";
#  594 :         param_names__.push_back(param_name_stream__.str());
#  595 :
#  596 :         if (!include_gqs__ && !include_tparams__) return;
#  597 :         for (int k_0__ = 1; k_0__ <= J; ++k_0__) {
#  598 :             param_name_stream__.str(std::string());
#  599 :             param_name_stream__ << "p" << '.' << k_0__;
#  600 :             param_names__.push_back(param_name_stream__.str());
#  601 :         }
#  602 :         for (int k_0__ = 1; k_0__ <= J; ++k_0__) {
#  603 :             param_name_stream__.str(std::string());
#  604 :             param_name_stream__ << "phi" << '.' << k_0__;
#  605 :             param_names__.push_back(param_name_stream__.str());
#  606 :         }
#  607 :
#  608 :         if (!include_gqs__) return;
#  609 :         param_name_stream__.str(std::string());
#  610 :         param_name_stream__ << "medianOR";
#  611 :         param_names__.push_back(param_name_stream__.str());
#  612 :     }
#  613 :
#  614 :
#  615 :     void unconstrained_param_names(std::vector<std::string>& param_names__,
#  616 :                                    bool include_tparams__ = true,
#  617 :                                    bool include_gqs__ = true) const {
#  618 :         std::stringstream param_name_stream__;
#  619 :         for (int k_0__ = 1; k_0__ <= J; ++k_0__) {
#  620 :             param_name_stream__.str(std::string());
#  621 :             param_name_stream__ << "delta" << '.' << k_0__;
#  622 :             param_names__.push_back(param_name_stream__.str());
#  623 :         }
#  624 :         for (int k_0__ = 1; k_0__ <= J; ++k_0__) {
#  625 :             param_name_stream__.str(std::string());
#  626 :             param_name_stream__ << "q" << '.' << k_0__;
#  627 :             param_names__.push_back(param_name_stream__.str());
#  628 :         }
#  629 :         param_name_stream__.str(std::string());
#  630 :         param_name_stream__ << "tau";
#  631 :         param_names__.push_back(param_name_stream__.str());
#  632 :         param_name_stream__.str(std::string());
#  633 :         param_name_stream__ << "mu";
#  634 :         param_names__.push_back(param_name_stream__.str());
#  635 :
#  636 :         if (!include_gqs__ && !include_tparams__) return;
#  637 :         for (int k_0__ = 1; k_0__ <= J; ++k_0__) {
#  638 :             param_name_stream__.str(std::string());
#  639 :             param_name_stream__ << "p" << '.' << k_0__;
#  640 :             param_names__.push_back(param_name_stream__.str());
#  641 :         }
#  642 :         for (int k_0__ = 1; k_0__ <= J; ++k_0__) {
#  643 :             param_name_stream__.str(std::string());
#  644 :             param_name_stream__ << "phi" << '.' << k_0__;
#  645 :             param_names__.push_back(param_name_stream__.str());
#  646 :         }
#  647 :
#  648 :         if (!include_gqs__) return;
#  649 :         param_name_stream__.str(std::string());
#  650 :         param_name_stream__ << "medianOR";
#  651 :         param_names__.push_back(param_name_stream__.str());
#  652 :     }
#  653 :
#  654 : }; // model
#  655 :
#  656 : }
#  657 :
#  658 : typedef model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7 stan_model;
#  659 :
#  660 : #include <rstan/rstaninc.hpp>
#  661 : /**
#  662 :  * Define Rcpp Module to expose stan_fit's functions to R.
#  663 :  */
#  664 : RCPP_MODULE(stan_fit4model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_mod){
#  665 :   Rcpp::class_<rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7,
#  666 :                boost::random::ecuyer1988> >("stan_fit4model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7")
#  667 :     // .constructor<Rcpp::List>()
#  668 :     .constructor<SEXP, SEXP, SEXP>()
#  669 :     // .constructor<SEXP, SEXP>()
#  670 :     .method("call_sampler",
#  671 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::call_sampler)
#  672 :     .method("param_names",
#  673 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::param_names)
#  674 :     .method("param_names_oi",
#  675 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::param_names_oi)
#  676 :     .method("param_fnames_oi",
#  677 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::param_fnames_oi)
#  678 :     .method("param_dims",
#  679 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::param_dims)
#  680 :     .method("param_dims_oi",
#  681 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::param_dims_oi)
#  682 :     .method("update_param_oi",
#  683 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::update_param_oi)
#  684 :     .method("param_oi_tidx",
#  685 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::param_oi_tidx)
#  686 :     .method("grad_log_prob",
#  687 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::grad_log_prob)
#  688 :     .method("log_prob",
#  689 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::log_prob)
#  690 :     .method("unconstrain_pars",
#  691 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::unconstrain_pars)
#  692 :     .method("constrain_pars",
#  693 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::constrain_pars)
#  694 :     .method("num_pars_unconstrained",
#  695 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::num_pars_unconstrained)
#  696 :     .method("unconstrained_param_names",
#  697 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::unconstrained_param_names)
#  698 :     .method("constrained_param_names",
#  699 :             &rstan::stan_fit<model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7_namespace::model3986156f7247_be8ceb788a44a6e7bcdeb561d91170b7, boost::random::ecuyer1988>::constrained_param_names)
#  700 :     ;
#  701 : }
#  702 :
#  703 : // declarations
#  704 : extern "C" {
#  705 : SEXP file398647b79e4f( ) ;
#  706 : }
#  707 :
#  708 : // definition
#  709 :
#  710 : SEXP file398647b79e4f(  ){
#  711 :  return Rcpp::wrap("be8ceb788a44a6e7bcdeb561d91170b7");
#  712 : }
#  713 :
#  714 :
# Compilation argument:
#  /Library/Frameworks/R.framework/Resources/bin/R CMD SHLIB file398647b79e4f.cpp 2> file398647b79e4f.cpp.err.txt
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core.hpp:12:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core/gevv_vvv_vari.hpp:5:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core/var.hpp:7:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/math/tools/config.hpp:13:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/config.hpp:39:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/config/compiler/clang.hpp:200:11: warning: 'BOOST_NO_CXX11_RVALUE_REFERENCES' macro redefined [-Wmacro-redefined]
# #  define BOOST_NO_CXX11_RVALUE_REFERENCES
#           ^
# <command line>:6:9: note: previous definition is here
# #define BOOST_NO_CXX11_RVALUE_REFERENCES 1
#         ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core.hpp:14:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core/matrix_vari.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat/fun/Eigen_NumTraits.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/Eigen.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Dense:1:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Core:531:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:10:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core.hpp:14:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core/matrix_vari.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat/fun/Eigen_NumTraits.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/Eigen.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Dense:2:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/LU:47:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:10:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core.hpp:14:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core/matrix_vari.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat/fun/Eigen_NumTraits.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/Eigen.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Dense:3:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Cholesky:12:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Jacobi:29:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:10:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core.hpp:14:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core/matrix_vari.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat/fun/Eigen_NumTraits.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/Eigen.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Dense:3:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Cholesky:43:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:10:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core.hpp:14:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core/matrix_vari.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat/fun/Eigen_NumTraits.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/Eigen.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Dense:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/QR:17:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Householder:27:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:10:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core.hpp:14:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core/matrix_vari.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat/fun/Eigen_NumTraits.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/Eigen.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Dense:5:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/SVD:48:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:10:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core.hpp:14:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core/matrix_vari.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat/fun/Eigen_NumTraits.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/Eigen.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Dense:6:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Geometry:58:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:10:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core.hpp:14:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core/matrix_vari.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat/fun/Eigen_NumTraits.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/Eigen.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Dense:7:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Eigenvalues:58:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:10:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core.hpp:36:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core/operator_unary_plus.hpp:7:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/scal/fun/constants.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/math/constants/constants.hpp:13:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/math/tools/convert_from_string.hpp:15:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/lexical_cast.hpp:32:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/lexical_cast/try_lexical_convert.hpp:42:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/lexical_cast/detail/converter_lexical.hpp:52:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/container/container_fwd.hpp:61:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/container/detail/std_fwd.hpp:27:1: warning: inline namespaces are a C++11 feature [-Wc++11-inline-namespace]
# BOOST_MOVE_STD_NS_BEG
# ^
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/move/detail/std_ns_begin.hpp:18:34: note: expanded from macro 'BOOST_MOVE_STD_NS_BEG'
#    #define BOOST_MOVE_STD_NS_BEG _LIBCPP_BEGIN_NAMESPACE_STD
#                                  ^
# /anaconda3/bin/../include/c++/v1/__config:388:52: note: expanded from macro '_LIBCPP_BEGIN_NAMESPACE_STD'
# #define _LIBCPP_BEGIN_NAMESPACE_STD namespace std {inline namespace _LIBCPP_NAMESPACE {
#                                                    ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:12:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat.hpp:83:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/csr_extract_u.hpp:6:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Sparse:26:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/SparseCore:66:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:10:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:12:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat.hpp:83:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/csr_extract_u.hpp:6:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Sparse:27:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/OrderingMethods:71:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:10:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:12:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat.hpp:83:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/csr_extract_u.hpp:6:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Sparse:29:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/SparseCholesky:43:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:10:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:12:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat.hpp:83:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/csr_extract_u.hpp:6:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Sparse:32:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/SparseQR:35:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:10:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:12:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat.hpp:83:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/csr_extract_u.hpp:6:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/Sparse:33:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/IterativeLinearSolvers:46:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:10:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from file398647b79e4f.cpp:660:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/rstan/include/rstan/rstaninc.hpp:3:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/rstan/include/rstan/stan_fit.hpp:36:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/services/optimize/bfgs.hpp:11:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/optimization/bfgs.hpp:9:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/optimization/lbfgs_update.hpp:6:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/circular_buffer.hpp:54:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/circular_buffer/details.hpp:20:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/move/move.hpp:30:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/move/iterator.hpp:27:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/move/detail/iterator_traits.hpp:29:1: warning: inline namespaces are a C++11 feature [-Wc++11-inline-namespace]
# BOOST_MOVE_STD_NS_BEG
# ^
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/BH/include/boost/move/detail/std_ns_begin.hpp:18:34: note: expanded from macro 'BOOST_MOVE_STD_NS_BEG'
#    #define BOOST_MOVE_STD_NS_BEG _LIBCPP_BEGIN_NAMESPACE_STD
#                                  ^
# /anaconda3/bin/../include/c++/v1/__config:388:52: note: expanded from macro '_LIBCPP_BEGIN_NAMESPACE_STD'
# #define _LIBCPP_BEGIN_NAMESPACE_STD namespace std {inline namespace _LIBCPP_NAMESPACE {
#                                                    ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core.hpp:44:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core/set_zero_all_adjoints.hpp:14:17: warning: unused function 'set_zero_all_adjoints' [-Wunused-function]
#     static void set_zero_all_adjoints() {
#                 ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core.hpp:45:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/core/set_zero_all_adjoints_nested.hpp:17:17: warning: 'static' function 'set_zero_all_adjoints_nested' declared in header file should be declared 'static inline' [-Wunneeded-internal-declaration]
#     static void set_zero_all_adjoints_nested() {
#                 ^
# In file included from file398647b79e4f.cpp:8:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/src/stan/model/model_header.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math.hpp:4:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/rev/mat.hpp:12:
# In file included from /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat.hpp:58:
# /Library/Frameworks/R.framework/Versions/3.4/Resources/library/StanHeaders/include/stan/math/prim/mat/fun/autocorrelation.hpp:17:14: warning: function 'fft_next_good_size' is not needed and will not be emitted [-Wunneeded-internal-declaration]
#       size_t fft_next_good_size(size_t N) {
#              ^
# 19 warnings generated.
#
# CHECKING DATA AND PREPROCESSING FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# COMPILING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# STARTING SAMPLER FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.

# %%
data_frame(v1=rstan::extract(stan_samples_1.0,par="medianOR")$medianOR) %>% 
count(v1<1) %>% mutate(prop=n/sum(n))
# Out:
#   v1 < 1 n    prop
# 1 FALSE     2 0.0005
# 2  TRUE  3998 0.9995

# %%
my_output_df_one = c("1.0") %>% map_df(~one_stan_out(.))
write_csv(my_output_df_one,here("results/stan_out_1.0.csv"))

# %%
data_list[["eta"]] = 0.001
stan_samples_0.001 <- stan(model_code = mag_code, data = data_list,verbose=T)
# Out:
# TRANSLATING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' FROM Stan CODE TO C++ CODE NOW.
# successful in parsing the Stan model 'be8ceb788a44a6e7bcdeb561d91170b7'.
#
# CHECKING DATA AND PREPROCESSING FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# COMPILING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# STARTING SAMPLER FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.

# %%
data_frame(v1=rstan::extract(stan_samples_0.001,par="medianOR")$medianOR) %>% 
count(v1<1) %>% mutate(prop=n/sum(n))
# Out:
#   v1 < 1 n    prop
# 1 FALSE  1978 0.4945
# 2  TRUE  2022 0.5055

# %%
my_output_df_0.001 = c("0.001") %>% map_df(~one_stan_out(.))
write_csv(my_output_df_0.001,here("results/stan_out_001.csv"))

# %%
data_list[["eta"]] = 0.55
stan_samples_0.55 <- stan(model_code = mag_code, data = data_list,verbose=T)
# Out:
# TRANSLATING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' FROM Stan CODE TO C++ CODE NOW.
# successful in parsing the Stan model 'be8ceb788a44a6e7bcdeb561d91170b7'.
#
# CHECKING DATA AND PREPROCESSING FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# COMPILING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# STARTING SAMPLER FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.

# %%
data_frame(v1=rstan::extract(stan_samples_0.55,par="medianOR")$medianOR) %>% 
count(v1<1) %>% mutate(prop=n/sum(n))
# Out:
#   v1 < 1 n    prop
# 1 FALSE     2 0.0005
# 2  TRUE  3998 0.9995

# %%
my_output_df_0.55 = c("0.55") %>% map_df(~one_stan_out(.))
write_csv(my_output_df_0.55,here("results/stan_out_55.csv"))

# %%
data_list[["eta"]] = 0.86
stan_samples_0.86 <- stan(model_code = mag_code, data = data_list,verbose=T)
# Out:
# TRANSLATING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' FROM Stan CODE TO C++ CODE NOW.
# successful in parsing the Stan model 'be8ceb788a44a6e7bcdeb561d91170b7'.
#
# CHECKING DATA AND PREPROCESSING FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# COMPILING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# STARTING SAMPLER FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.

# %%
data_frame(v1=rstan::extract(stan_samples_0.86,par="medianOR")$medianOR) %>% 
count(v1<1) %>% mutate(prop=n/sum(n))
# Out:
#   v1 < 1 n    prop
# 1 FALSE     2 0.0005
# 2  TRUE  3998 0.9995

# %%
my_output_df_0.86 = c("0.86") %>% map_df(~one_stan_out(.))
write_csv(my_output_df_0.86,here("results/stan_out_86.csv"))

# %%
data_list[["eta"]] = 0.11
stan_samples_0.11 <- stan(model_code = mag_code, data = data_list,verbose=T)
# Out:
# TRANSLATING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' FROM Stan CODE TO C++ CODE NOW.
# successful in parsing the Stan model 'be8ceb788a44a6e7bcdeb561d91170b7'.
#
# CHECKING DATA AND PREPROCESSING FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# COMPILING MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.
#
# STARTING SAMPLER FOR MODEL 'be8ceb788a44a6e7bcdeb561d91170b7' NOW.

# %%
data_frame(v1=rstan::extract(stan_samples_0.11,par="medianOR")$medianOR) %>% 
count(v1<1) %>% mutate(prop=n/sum(n))
# Out:
#   v1 < 1 n    prop
# 1 FALSE   389 0.09725
# 2  TRUE  3611 0.90275

# %%
my_output_df_0.11 = c("0.11") %>% map_df(~one_stan_out(.))
write_csv(my_output_df_0.11,here("results/stan_out_11.csv"))

# %%
### Needed to run twice due to bad warmup on seed
data_list[["eta"]] = 0.11
stan_samples_0.11 <- stan(model_code = mag_code, data = data_list,verbose=T)
data_frame(v1=rstan::extract(stan_samples_0.11,par="medianOR")$medianOR) %>% 
count(v1<1) %>% mutate(prop=n/sum(n))
my_output_df_0.11 = c("0.11") %>% map_df(~one_stan_out(.))
write_csv(my_output_df_0.11,here("results/stan_out_11.csv"))
